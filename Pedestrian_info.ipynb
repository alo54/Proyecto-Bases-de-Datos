# %%
import pandas as pd

# Usa una raw string para evitar problemas con las diagonales invertidas
ruta = r"C:\Users\ricar\Downloads\Traffic_Crashes_-_People_20251124.csv"
df = pd.read_csv(ruta)

df.head()  # para ver las primeras filas
# Out:
# C:\Users\ricar\AppData\Local\Temp\ipykernel_23016\3727312589.py:5: DtypeWarning: Columns (28) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(ruta)
#   PERSON_ID PERSON_TYPE                                    CRASH_RECORD_ID  \
# 0  O2196169      DRIVER  e0407fea51e7416bf7d9a0a180c2e63b574656e04799b8...
# 1  O2196168      DRIVER  bf747a52a9c25310c3c1563ed185caa45dd2f8982ac184...
# 2   P484166   PASSENGER  bf747a52a9c25310c3c1563ed185caa45dd2f8982ac184...
# 3  O2196167      DRIVER  2220504a14186a4f588c2b2f485007ea248c46acedc51e...
# 4   P484164   PASSENGER  2220504a14186a4f588c2b2f485007ea248c46acedc51e...
#
#    VEHICLE_ID              CRASH_DATE  SEAT_NO     CITY STATE ZIPCODE  SEX  \
# 0   2093317.0  11/24/2025 01:40:00 AM      NaN      NaN   NaN     NaN    X
# 1   2093318.0  11/24/2025 01:34:00 AM      NaN  CHICAGO    IL   60629    M
# 2   2093318.0  11/24/2025 01:34:00 AM      3.0  CHICAGO    IL   60629    M
# ...

# %%
df.columns.tolist()
# Out:
# ['PERSON_ID',
#  'PERSON_TYPE',
#  'CRASH_RECORD_ID',
#  'VEHICLE_ID',
#  'CRASH_DATE',
#  'SEAT_NO',
#  'CITY',
#  'STATE',
#  'ZIPCODE',
#  'SEX',
#  'AGE',
#  'DRIVERS_LICENSE_STATE',
#  'DRIVERS_LICENSE_CLASS',
#  'SAFETY_EQUIPMENT',
#  'AIRBAG_DEPLOYED',
#  'EJECTION',
#  'INJURY_CLASSIFICATION',
#  'HOSPITAL',
#  'EMS_AGENCY',
#  'EMS_RUN_NO',
#  'DRIVER_ACTION',
#  'DRIVER_VISION',
#  'PHYSICAL_CONDITION',
#  'PEDPEDAL_ACTION',
#  'PEDPEDAL_VISIBILITY',
#  'PEDPEDAL_LOCATION',
#  'BAC_RESULT',
#  'BAC_RESULT VALUE',
#  'CELL_PHONE_USE']

# %%
pedestrian_info = df[
    [
        'PERSON_ID',
        'PEDPEDAL_ACTION',
        'PEDPEDAL_VISIBILITY',
        'PEDPEDAL_LOCATION'
    ]
].copy()

pedestrian_info.head()
# Out:
#   PERSON_ID PEDPEDAL_ACTION PEDPEDAL_VISIBILITY PEDPEDAL_LOCATION
# 0  O2196169             NaN                 NaN               NaN
# 1  O2196168             NaN                 NaN               NaN
# 2   P484166             NaN                 NaN               NaN
# 3  O2196167             NaN                 NaN               NaN
# 4   P484164             NaN                 NaN               NaN

# %%
pedestrian_info.isna().sum()
# Out:
# PERSON_ID                    0
# PEDPEDAL_ACTION        2162643
# PEDPEDAL_VISIBILITY    2162724
# PEDPEDAL_LOCATION      2162642
# dtype: int64

# %%
pedestrian_info.isna().mean()*100
# Out:
# PERSON_ID               0.000000
# PEDPEDAL_ACTION        97.978625
# PEDPEDAL_VISIBILITY    97.982295
# PEDPEDAL_LOCATION      97.978580
# dtype: float64

# %%
pedestrian_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2207260 entries, 0 to 2207259
# Data columns (total 4 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   PERSON_ID            object
#  1   PEDPEDAL_ACTION      object
#  2   PEDPEDAL_VISIBILITY  object
#  3   PEDPEDAL_LOCATION    object
# dtypes: object(4)
# memory usage: 67.4+ MB

# %%
pedestrian_info.apply(lambda col:col.astype(str).str.upper().eq("UNKWON").sum())
# Out:
# PERSON_ID              0
# PEDPEDAL_ACTION        0
# PEDPEDAL_VISIBILITY    0
# PEDPEDAL_LOCATION      0
# dtype: int64

# %%
pedestrian_info.apply(lambda col:col.astype(str).str.upper().eq("NAN").sum())
# Out:
# PERSON_ID                    0
# PEDPEDAL_ACTION        2162643
# PEDPEDAL_VISIBILITY    2162724
# PEDPEDAL_LOCATION      2162642
# dtype: int64

# %%
pedestrian_info.apply(lambda col:col.astype(str).str.upper().eq("N").sum())
# Out:
# PERSON_ID              0
# PEDPEDAL_ACTION        0
# PEDPEDAL_VISIBILITY    0
# PEDPEDAL_LOCATION      0
# dtype: int64

# %%
pedestrian_info.apply(lambda col:col.astype(str).str.upper().eq("").sum())
# Out:
# PERSON_ID              0
# PEDPEDAL_ACTION        0
# PEDPEDAL_VISIBILITY    0
# PEDPEDAL_LOCATION      0
# dtype: int64

# %%
pedestrian_info = pedestrian_info.where(pedestrian_info.notna(), None)

# %%
pedestrian_info.head()
# Out:
#   PERSON_ID PEDPEDAL_ACTION PEDPEDAL_VISIBILITY PEDPEDAL_LOCATION
# 0  O2196169            None                None              None
# 1  O2196168            None                None              None
# 2   P484166            None                None              None
# 3  O2196167            None                None              None
# 4   P484164            None                None              None

# %%
pedestrian_info.isnull().sum()
# Out:
# PERSON_ID                    0
# PEDPEDAL_ACTION        2162643
# PEDPEDAL_VISIBILITY    2162724
# PEDPEDAL_LOCATION      2162642
# dtype: int64

# %%
pedestrian_info.isna().sum()
# Out:
# PERSON_ID                    0
# PEDPEDAL_ACTION        2162643
# PEDPEDAL_VISIBILITY    2162724
# PEDPEDAL_LOCATION      2162642
# dtype: int64

# %%
ruta_salida = r"C:\Users\ricar\Downloads\Pedestrian_Info.csv"
pedestrian_info.to_csv(ruta_salida, index=False)
