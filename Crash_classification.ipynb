# %%
import pandas as pd

# Usa una raw string para evitar problemas con las diagonales invertidas
ruta = r"C:\Users\ricar\Downloads\Traffic_Crashes_-_Crashes_20251125.csv"

df = pd.read_csv(ruta)

df.head()  # para ver las primeras filas
# Out:
# C:\Users\ricar\AppData\Local\Temp\ipykernel_20368\788281011.py:6: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(ruta)
#                                      CRASH_RECORD_ID CRASH_DATE_EST_I  \
# 0  1a1868381b5e43b6b709a96ca7aa9673d4230fa0c16116...              NaN
# 1  602ab139af91e70c6e6966f7878a4a06d11cd76b3f1158...              NaN
# 2  0936a6f1e379879e4ce1735469a4097c49980bbffbf7e6...                Y
# 3  cd3712068bcd1c74d85c49660354440923e73e205c26e4...              NaN
# 4  ab96848e9eb1e48b3e5c7eedeabea1f426279ba4339ffd...              NaN
#
#                CRASH_DATE  POSTED_SPEED_LIMIT TRAFFIC_CONTROL_DEVICE  \
# 0  11/24/2025 11:39:00 PM                  30         TRAFFIC SIGNAL
# 1  11/24/2025 11:14:00 PM                  30            NO CONTROLS
# 2  11/24/2025 09:30:00 PM                  30                  OTHER
# 3  11/24/2025 09:30:00 PM                  30            NO CONTROLS
# ...

# %%
df.columns.tolist()
# Out:
# ['CRASH_RECORD_ID',
#  'CRASH_DATE_EST_I',
#  'CRASH_DATE',
#  'POSTED_SPEED_LIMIT',
#  'TRAFFIC_CONTROL_DEVICE',
#  'DEVICE_CONDITION',
#  'WEATHER_CONDITION',
#  'LIGHTING_CONDITION',
#  'FIRST_CRASH_TYPE',
#  'TRAFFICWAY_TYPE',
#  'LANE_CNT',
#  'ALIGNMENT',
#  'ROADWAY_SURFACE_COND',
#  'ROAD_DEFECT',
#  'REPORT_TYPE',
#  'CRASH_TYPE',
#  'INTERSECTION_RELATED_I',
#  'NOT_RIGHT_OF_WAY_I',
#  'HIT_AND_RUN_I',
#  'DAMAGE',
#  'DATE_POLICE_NOTIFIED',
#  'PRIM_CONTRIBUTORY_CAUSE',
#  'SEC_CONTRIBUTORY_CAUSE',
#  'STREET_NO',
#  'STREET_DIRECTION',
#  'STREET_NAME',
#  'BEAT_OF_OCCURRENCE',
#  'PHOTOS_TAKEN_I',
#  'STATEMENTS_TAKEN_I',
#  'DOORING_I',
#  'WORK_ZONE_I',
#  'WORK_ZONE_TYPE',
#  'WORKERS_PRESENT_I',
#  'NUM_UNITS',
#  'MOST_SEVERE_INJURY',
#  'INJURIES_TOTAL',
#  'INJURIES_FATAL',
#  'INJURIES_INCAPACITATING',
#  'INJURIES_NON_INCAPACITATING',
#  'INJURIES_REPORTED_NOT_EVIDENT',
#  'INJURIES_NO_INDICATION',
#  'INJURIES_UNKNOWN',
#  'CRASH_HOUR',
#  'CRASH_DAY_OF_WEEK',
# ...

# %%
cols = [
    'CRASH_RECORD_ID',
    'FIRST_CRASH_TYPE',
    'CRASH_TYPE',
    'PRIM_CONTRIBUTORY_CAUSE',
    'SEC_CONTRIBUTORY_CAUSE',
    'DAMAGE',
    'HIT_AND_RUN_I'
]

crash_classification = df[cols].copy()
crash_classification.head()
# Out:
#                                      CRASH_RECORD_ID  \
# 0  1a1868381b5e43b6b709a96ca7aa9673d4230fa0c16116...
# 1  602ab139af91e70c6e6966f7878a4a06d11cd76b3f1158...
# 2  0936a6f1e379879e4ce1735469a4097c49980bbffbf7e6...
# 3  cd3712068bcd1c74d85c49660354440923e73e205c26e4...
# 4  ab96848e9eb1e48b3e5c7eedeabea1f426279ba4339ffd...
#
#            FIRST_CRASH_TYPE                        CRASH_TYPE  \
# 0  SIDESWIPE SAME DIRECTION            NO INJURY / DRIVE AWAY
# 1                  REAR END            NO INJURY / DRIVE AWAY
# 2  SIDESWIPE SAME DIRECTION            NO INJURY / DRIVE AWAY
# 3                   TURNING  INJURY AND / OR TOW DUE TO CRASH
# 4                     ANGLE  INJURY AND / OR TOW DUE TO CRASH
#
#   PRIM_CONTRIBUTORY_CAUSE SEC_CONTRIBUTORY_CAUSE         DAMAGE HIT_AND_RUN_I
# 0     IMPROPER LANE USAGE    IMPROPER LANE USAGE  $501 - $1,500           NaN
# 1          NOT APPLICABLE         NOT APPLICABLE    OVER $1,500             N
# ...

# %%
crash_classification.isna().sum()
# Out:
# CRASH_RECORD_ID                 0
# FIRST_CRASH_TYPE                0
# CRASH_TYPE                      0
# PRIM_CONTRIBUTORY_CAUSE         0
# SEC_CONTRIBUTORY_CAUSE          0
# DAMAGE                          0
# HIT_AND_RUN_I              689954
# dtype: int64

# %%
crash_classification.isna().mean()*100
# Out:
# CRASH_RECORD_ID             0.00000
# FIRST_CRASH_TYPE            0.00000
# CRASH_TYPE                  0.00000
# PRIM_CONTRIBUTORY_CAUSE     0.00000
# SEC_CONTRIBUTORY_CAUSE      0.00000
# DAMAGE                      0.00000
# HIT_AND_RUN_I              68.62039
# dtype: float64

# %%
crash_classification.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1005465 entries, 0 to 1005464
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   CRASH_RECORD_ID          1005465 non-null  object
#  1   FIRST_CRASH_TYPE         1005465 non-null  object
#  2   CRASH_TYPE               1005465 non-null  object
#  3   PRIM_CONTRIBUTORY_CAUSE  1005465 non-null  object
#  4   SEC_CONTRIBUTORY_CAUSE   1005465 non-null  object
#  5   DAMAGE                   1005465 non-null  object
#  6   HIT_AND_RUN_I            315511 non-null   object
# dtypes: object(7)
# memory usage: 53.7+ MB

# %%
crash_classification.apply(lambda col:col.astype(str).str.upper().eq("UNKWON").sum())
# Out:
# CRASH_RECORD_ID            0
# FIRST_CRASH_TYPE           0
# CRASH_TYPE                 0
# PRIM_CONTRIBUTORY_CAUSE    0
# SEC_CONTRIBUTORY_CAUSE     0
# DAMAGE                     0
# HIT_AND_RUN_I              0
# dtype: int64

# %%
crash_classification.apply(lambda col:col.astype(str).str.upper().eq("NAN").sum())
# Out:
# CRASH_RECORD_ID                 0
# FIRST_CRASH_TYPE                0
# CRASH_TYPE                      0
# PRIM_CONTRIBUTORY_CAUSE         0
# SEC_CONTRIBUTORY_CAUSE          0
# DAMAGE                          0
# HIT_AND_RUN_I              689954
# dtype: int64

# %%
crash_classification.apply(lambda col:col.astype(str).str.upper().eq("N").sum())
# Out:
# CRASH_RECORD_ID                0
# FIRST_CRASH_TYPE               0
# CRASH_TYPE                     0
# PRIM_CONTRIBUTORY_CAUSE        0
# SEC_CONTRIBUTORY_CAUSE         0
# DAMAGE                         0
# HIT_AND_RUN_I              13555
# dtype: int64

# %%
crash_classification.apply(lambda col:col.astype(str).str.upper().eq("").sum())
# Out:
# CRASH_RECORD_ID            0
# FIRST_CRASH_TYPE           0
# CRASH_TYPE                 0
# PRIM_CONTRIBUTORY_CAUSE    0
# SEC_CONTRIBUTORY_CAUSE     0
# DAMAGE                     0
# HIT_AND_RUN_I              0
# dtype: int64

# %%
crash_classification = crash_classification.where(crash_classification.notna(), None)

# %%
crash_classification.isnull().sum()
# Out:
# CRASH_RECORD_ID                 0
# FIRST_CRASH_TYPE                0
# CRASH_TYPE                      0
# PRIM_CONTRIBUTORY_CAUSE         0
# SEC_CONTRIBUTORY_CAUSE          0
# DAMAGE                          0
# HIT_AND_RUN_I              689954
# dtype: int64

# %%
crash_classification.head()
# Out:
#                                      CRASH_RECORD_ID  \
# 0  1a1868381b5e43b6b709a96ca7aa9673d4230fa0c16116...
# 1  602ab139af91e70c6e6966f7878a4a06d11cd76b3f1158...
# 2  0936a6f1e379879e4ce1735469a4097c49980bbffbf7e6...
# 3  cd3712068bcd1c74d85c49660354440923e73e205c26e4...
# 4  ab96848e9eb1e48b3e5c7eedeabea1f426279ba4339ffd...
#
#            FIRST_CRASH_TYPE                        CRASH_TYPE  \
# 0  SIDESWIPE SAME DIRECTION            NO INJURY / DRIVE AWAY
# 1                  REAR END            NO INJURY / DRIVE AWAY
# 2  SIDESWIPE SAME DIRECTION            NO INJURY / DRIVE AWAY
# 3                   TURNING  INJURY AND / OR TOW DUE TO CRASH
# 4                     ANGLE  INJURY AND / OR TOW DUE TO CRASH
#
#   PRIM_CONTRIBUTORY_CAUSE SEC_CONTRIBUTORY_CAUSE         DAMAGE HIT_AND_RUN_I
# 0     IMPROPER LANE USAGE    IMPROPER LANE USAGE  $501 - $1,500          None
# 1          NOT APPLICABLE         NOT APPLICABLE    OVER $1,500             N
# ...

# %%
crash_classification = crash_classification.replace("N", None)

# %%
crash_classification.apply(lambda col: (col == "N").sum())
# Out:
# CRASH_RECORD_ID            0
# FIRST_CRASH_TYPE           0
# CRASH_TYPE                 0
# PRIM_CONTRIBUTORY_CAUSE    0
# SEC_CONTRIBUTORY_CAUSE     0
# DAMAGE                     0
# HIT_AND_RUN_I              0
# dtype: int64

# %%
crash_classification.head()
# Out:
#                                      CRASH_RECORD_ID  \
# 0  1a1868381b5e43b6b709a96ca7aa9673d4230fa0c16116...
# 1  602ab139af91e70c6e6966f7878a4a06d11cd76b3f1158...
# 2  0936a6f1e379879e4ce1735469a4097c49980bbffbf7e6...
# 3  cd3712068bcd1c74d85c49660354440923e73e205c26e4...
# 4  ab96848e9eb1e48b3e5c7eedeabea1f426279ba4339ffd...
#
#            FIRST_CRASH_TYPE                        CRASH_TYPE  \
# 0  SIDESWIPE SAME DIRECTION            NO INJURY / DRIVE AWAY
# 1                  REAR END            NO INJURY / DRIVE AWAY
# 2  SIDESWIPE SAME DIRECTION            NO INJURY / DRIVE AWAY
# 3                   TURNING  INJURY AND / OR TOW DUE TO CRASH
# 4                     ANGLE  INJURY AND / OR TOW DUE TO CRASH
#
#   PRIM_CONTRIBUTORY_CAUSE SEC_CONTRIBUTORY_CAUSE         DAMAGE HIT_AND_RUN_I
# 0     IMPROPER LANE USAGE    IMPROPER LANE USAGE  $501 - $1,500          None
# 1          NOT APPLICABLE         NOT APPLICABLE    OVER $1,500          None
# ...

# %%
ruta_salida = r"C:\Users\ricar\Downloads\Pedestrian_Info.csv"
crash_classification.to_csv(ruta_salida, index=False)
